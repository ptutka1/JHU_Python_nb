# %% [markdown]
# # Pat Tutka
# # 13 April 2018

# %% [markdown]
# # Assignment 12 - Neural Networks image recognition
# Use both MLNN and the ConvNet to solve the following problem.
#
# 1. Add random noise (i.e. np.random.normal) to the images in training and testing. Make sure each image gets a different noise feature added to it. Inspect by printing out an image.
# 2. Compare the loss/accuracy (train, val) after N epochs for both MLNN and ConvNet with and without noise.
# 3. Vary the amount of noise (multiply np.random.normal by a factor) and keep track of the accuracy and loss (for training and validation) and plot these results.

# %% [markdown]
# For the week 12 assignment I tested both a basic MNIST and convoltuion neural networks running a total of 24 seperate iterations (60,000 images in training and 10,000 test validations) on a noisy network. I first ran both networks without noise to see how they performed. The basic MNIST net reported 0.2500 loss in training and 0.2100 loss in test with 10 epochs. Training accuracy was 0.9262 and test accuracy was 0.9387 respectively. The convolution network produced much better results after only 2 epochs. Training loss was 0.0874 and test loss was 0.0404. Training accuracy was 0.9732 and test accuracy was 0.9858. I conclude that the convolution network's prediction capability is impressive even after only 2 epochs. I would like to try this entire experiment again on a GPU and increase epochs on both networks.
#
# After applying a series of noise, both model's loss/error gradually increased and accuracy gradually decreased. To a certain extend it looks like a linear function or polynominal (second degree order) regression could fit both the loss and accuracy lines. The best results came from the convolution network because it performed well even after a conciderable amount of noise. After 100 additional pixel noise, the convolution's loss started to increase and accuracy began to decrease. I conclude that the convoultion network performed very well even with a conciderable amount of noise.

# %%
handwriting = pd.read_csv('C:\JHU_Python\Week12v2.csv')
handwriting
# Out:
#     ID  train_epoch  trainnoise   tloss  trainaccuracy  test_epoch  testnoise  \
# 0    1           10           0  0.2500         0.9262          10          0
# 1    2           10           1  0.2600         0.9253          10          1
# 2    3           10           2  0.2547         0.9259          10          2
# 3    4           10           3  0.2502         0.9269          10          3
# 4    5           10           4  0.2525         0.9261          10          4
# 5    6           10           5  0.2515         0.9272          10          5
# 6    7           10          10  0.2577         0.9254          10         10
# 7    8           10          15  0.2603         0.9239          10         15
# 8    9           10          20  0.2667         0.9218          10         20
# 9   10           10          25  0.2714         0.9205          10         25
# 10  11           10          30  0.2761         0.9188          10         30
# ...

# %%
plt.scatter(noise,trl1, label=None)
plt.scatter(noise,tl1, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, trl1, color='blue', label='Train')
plt.plot(noise, tl1, color='orange', label='Test')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("MNIST Neural Network Training/Test Loss vs. Noise")
plt.xlabel("Noise")
plt.ylabel("Loss")
# Out:
# Text(0,0.5,'Loss')

# %%
plt.scatter(noise,trl2, label=None)
plt.scatter(noise,tl2, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, trl2, color='blue', label='Train')
plt.plot(noise, tl2, color='orange', label='Test')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Convolution Neural Network Training/Test Loss vs. Noise 2 Epoch" )
plt.xlabel("Noise")
plt.ylabel("Loss")
# Out:
# Text(0,0.5,'Loss')

# %%
plt.scatter(noise,trl2, label=None)
plt.scatter(noise,trl1, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, trl2, color='blue', label='Convolution')
plt.plot(noise, trl1, color='orange', label='MNIST')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Model Comparison Training Loss vs. Noise" )
plt.xlabel("Noise")
plt.ylabel("Loss")
# Out:
# Text(0,0.5,'Loss')

# %%
plt.scatter(noise,tl2, label=None)
plt.scatter(noise,tl1, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, tl2, color='blue', label='Convolution')
plt.plot(noise, tl1, color='orange', label='MNIST')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Model Comparison Test Loss vs. Noise" )
plt.xlabel("Noise")
plt.ylabel("Loss")
# Out:
# Text(0,0.5,'Loss')

# %%
plt.scatter(noise,trac2, label=None)
plt.scatter(noise,trac1, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, trac2, color='blue', label='Convolution')
plt.plot(noise, trac1, color='orange', label='MNIST')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Model Compaprison Training Accuracy vs. Noise" )
plt.xlabel("Noise")
plt.ylabel("Accuracy")
# Out:
# Text(0,0.5,'Accuracy')

# %%
plt.scatter(noise,tac2, label=None)
plt.scatter(noise,tac1, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, tac2, color='blue', label='Convolution')
plt.plot(noise, tac1, color='orange', label='MNIST')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Model Compaprison Test Accuracy Loss vs. Noise" )
plt.xlabel("Noise")
plt.ylabel("Accuracy")
# Out:
# Text(0,0.5,'Accuracy')

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.optimizers import RMSprop
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt
# %matplotlib inline
# Out:
# C:\Users\Pat\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")
# C:\Users\Pat\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
xtrain = np.random.normal(x_train, 175)
xtest = np.random.normal(x_test, 175)
ytrain = y_train
ytest = y_test

# %%
plt.imshow(xtrain[2], cmap='gray')

# %%
xtrain = xtrain.reshape(60000, 784)
xtest = xtest.reshape(10000, 784)
xtrain = xtrain.astype('float32')
xtest = xtest.astype('float32')
xtrain /= 255
xtest /= 255
print(xtrain.shape[0], 'train samples')
print(xtest.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
num_classes=10

# %%
# convert class vectors to binary class matrices (0 and 1) 
ytrain = keras.utils.to_categorical(ytrain, num_classes)
ytest = keras.utils.to_categorical(ytest, num_classes)

# %% [markdown]
# # The model starts here:

# %%
batch_size = 128
num_classes = 10
epochs = 10


model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2)) #disconnects some of the neurons as to not overfit
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax')) #probability that one of the outputs is the highest

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

history = model.fit(xtrain, ytrain,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(xtest, ytest))
score = model.evaluate(xtest, ytest, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_25 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 10)                5130
# ...
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# ...

# %% [markdown]
# # Convo Network

# %%
# the data, shuffled and split between train and test sets
(x_train1, y_train), (x_test1, y_test) = mnist.load_data()

# %%
x_train = np.random.normal(x_train1, 0)
x_test = np.random.normal(x_test1, 0)

# %%
plt.imshow(x_train[3], cmap='gray')

# %%
# input image dimensions
img_rows, img_cols = 28, 28


if backend.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
batch_size = 128
num_classes = 10
epochs = 2


model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/2
# 60000/60000 [==============================] - 330s 6ms/step - loss: 0.2583 - acc: 0.9207 - val_loss: 0.0595 - val_acc: 0.9810
# Epoch 2/2
# 60000/60000 [==============================] - 332s 6ms/step - loss: 0.0874 - acc: 0.9732 - val_loss: 0.0405 - val_acc: 0.9858
# Test loss: 0.040456426166160964
# Test accuracy: 0.9858

# %%
trl1 = handwriting.tloss
tl1 = handwriting.testloss
trac1 = handwriting.trainaccuracy
tac1 = handwriting.testaccuracy
trl2 = handwriting.m2trainloss
tl2 = handwriting.m2testloss
trac2 = handwriting.m2trainaccuracy
tac2 = handwriting.m2testaccuracy
noise = handwriting.testnoise

# %%
plt.scatter(noise,trl1, label=None)
plt.scatter(noise,tl1, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, trl1, color='blue', label='Train')
plt.plot(noise, tl1, color='orange', label='Test')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("MNIST Neural Network Training/Test Loss vs. Noise")
plt.xlabel("Noise")
plt.ylabel("Loss")
# Out:
# Text(0,0.5,'Loss')

# %%
plt.scatter(noise,trl2, label=None)
plt.scatter(noise,tl2, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, trl2, color='blue', label='Train')
plt.plot(noise, tl2, color='orange', label='Test')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Convolution Neural Network Training/Test Loss vs. Noise 2 Epoch" )
plt.xlabel("Noise")
plt.ylabel("Loss")
# Out:
# Text(0,0.5,'Loss')

# %%
plt.scatter(noise,trl2, label=None)
plt.scatter(noise,trl1, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, trl2, color='blue', label='Convolution')
plt.plot(noise, trl1, color='orange', label='MNIST')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Model Compaprison Training Loss vs. Noise" )
plt.xlabel("Noise")
plt.ylabel("Loss")
# Out:
# Text(0,0.5,'Loss')

# %%
plt.scatter(noise,tl2, label=None)
plt.scatter(noise,tl1, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, tl2, color='blue', label='Convolution')
plt.plot(noise, tl1, color='orange', label='MNIST')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Model Compaprison Test Loss vs. Noise" )
plt.xlabel("Noise")
plt.ylabel("Loss")
# Out:
# Text(0,0.5,'Loss')

# %%
plt.scatter(noise,trac2, label=None)
plt.scatter(noise,trac1, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, trac2, color='blue', label='Convolution')
plt.plot(noise, trac1, color='orange', label='MNIST')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Model Compaprison Training Accuracy vs. Noise" )
plt.xlabel("Noise")
plt.ylabel("Accuracy")
# Out:
# Text(0,0.5,'Accuracy')

# %%
plt.scatter(noise,tac2, label=None)
plt.scatter(noise,tac1, label=None)
##plt.scatter(noise,polytrain2)
#plt.scatter(Degree,polytest2)
plt.plot(noise, tac2, color='blue', label='Convolution')
plt.plot(noise, tac1, color='orange', label='MNIST')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Model Compaprison Test Accuracy Loss vs. Noise" )
plt.xlabel("Noise")
plt.ylabel("Accuracy")
# Out:
# Text(0,0.5,'Accuracy')
