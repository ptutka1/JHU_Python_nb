# %% [markdown]
# # Pat Tutka
# # 11 - Neural Networks
# # Part 1 - XOR
# Using the XOR dataset below, train (400 epochs) a neural network (NN) using 1, 2, 3, 4, and 5 hidden layers (where each layer has only 2 neurons). For each n layers, store the resulting loss score along with n. Plot the results to find what the optimal number of layers is.
# Repeat the above with 3-neuron and 4-neuron Hidden layers. How do these results compare to the 2 neuron layers?
# Using the most optimal configuraion (n-layers, k-neurons per layer), compare how tanh, sigmoid,softplus and relu effect the loss after 400 epochs. Try other Activation functions as well (https://keras.io/activations/)
# Instead of SGD try other optimizers and report on the loss score. (https://keras.io/optimizers/)
# # Part 2 - BYOD (Bring your own Dataset)
# Using your own dataset, experiment and find the best Neural Network configuration. You may use any resource to improve results, just reference it.
#
# While you may use any dataset, I'd prefer you didn't use the diabetes dataset used in the lesson.
#
# https://stackoverflow.com/questions/34673164/how-to-train-and-tune-an-artificial-multilayer-perceptron-neural-network-using-k
#
# https://keras.io/

# %% [markdown]
# # Part 1
# I started the XOR assignment by generating n=50 points and multiply the points by four thus creating 200 total points. Next, I visualized the generated points in a scatterplot to see where the data was clustered. Before I implemented a neural network, I thought about which shape would capture as much data as possible. I decided to try the Tanh activation because a sigmoid would not fit the data well. I choose sgd optimization for back propagation and binary cross-entropy to measure the loss/ error of the model. I ran 400 epochs and discovered that 3 hidden layers with 2 neurons produced the best results. Next I ran the model with 3 and 4 neurons through ( 1-5 ) hidden layers. I discovered that 3 hidden layers and 4 neurons per layer produced almost perfect results. Remarkably, 3 hidden layers produced the best results across all the models. Next, I compared several the available optimizations SGD, Adam, RMSprop, Adagrad, and Adadelta to see if different optimizations would improve the model. I discovered that there were slight variations in the loss (error) but SRG remained the best option. Lastly, Adam and RMSprop performed well and both optimizations would be good chooses for additional testing going forward.

# %% [markdown]
# # Part 2
# In part 2, I chose two separate datasets Mushroom Classification and a Breast Cancer Classification dataset. The purpose of the mushroom dataset was to determine if a mushroom is poisonous or edible. In my very first attempt with a Tanh (two hidden layers and two neuron) the network produced perfect results with nearly 0 loss and 100% accuracy. At this point I decided to move onto the breast cancer dataset to try a more difficult dataset. I once again began with Tanh (adam) and imported 29 dimensions into the network and ran 400 epochs. I received satisfactory results initially with 1 hidden layer and 2 neurons and 2 hidden layers and 2 neurons respectively (Loss 0.28 and 0.26). Interestingly, I didn't see positive results until I tested 4 hidden layers with 3 neurons (loss 0.27) and 5 hidden layers with 4 neurons (loss 0.30). Most of the loss was about 0.66 for almost all the network configurations. In the next step, I compared three additional activations (Sigmoid, Softmax, Relu) to Tanh's (adam opitimizer) optimal results 2 hidden layers and 2 neurons (0.26). The other models loss function did not decreased below 0.66. Instead of stopping here I tried Tanh’s second most optimal configuration (4 hidden and 3 neurons 0.27) against other activations and opitimizations. I discovered that the best model was Relu with four hidden layers and three neurons incorporating an Adadelta opitimization. The final loss was 0.12 with 400 epochs. See the table and scatterplot below for final results. The majority of the other networks' loss function did not decrease below 0.66. Lastly, I tried other optimizers to determine if the model could improve. The best configuration remained a Sigmoid with 4 hidden layers, 3 neurons, with adam optimization. (See plots below).
#
# https://www.kaggle.com/uciml/mushroom-classification/data (Mushroom dataset)
# https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29 (Breast Cancer dataset)

# %%
Tanh_loss
# Out:
#    Hidden  Tanh_2_neurons  Tanh_3_neurons  Tanh_4_neurons
# 0       1          0.3294          0.1383          0.0707
# 1       2          0.0311          0.3286          0.4002
# 2       3          0.0221          0.0341          0.0060
# 3       4          0.3400          0.0277          0.0366
# 4       5          0.0534          0.0431          0.0496

# %%
plt.scatter(Hidden, Tanh_2_neurons, color='blue', label=None)
plt.scatter(Hidden, Tanh_3_neurons, color='orange', label=None)
plt.scatter(Hidden, Tanh_4_neurons, color='red', label=None)
plt.plot(Hidden, Tanh_2_neurons, color='blue', label='2 Neurons')
plt.plot(Hidden, Tanh_3_neurons, color='orange', label='3 Neurons')
plt.plot(Hidden, Tanh_4_neurons, color='red', label='4 Neurons')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Neural Network Hyperbolic Tangent Error (XOR) ")
plt.xlabel("Number of Hidden Layers")
plt.ylabel("Loss (Binary-cross Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary-cross Entropy)')

# %%
loss2
# Out:
#     Tanh1  Sigmoid1  Softmax1   Relu1       Opt
# 0  0.0060    0.6941    0.6928  0.2270       SGD
# 1  0.0154    0.5561    0.0190  0.0195      Adam
# 2  0.0816    0.1057    0.0167  0.5126   RMSprop
# 3  0.3390    0.6931    0.6286  0.0830   Adagrad
# 4  0.0614    0.3301    0.0558  0.0708  Adadelta

# %%
#plt.scatter(code, Tanh, color='blue', label=None)
#plt.scatter(code, Sigmoid, color='orange', label=None)
#plt.scatter(code, Softmax, color='red', label=None)
#plt.scatter(code, Relu, color='green', label=None)
#plt.scatter(code, Softsign, color='pink', label=None)
#plt.scatter(code, Selu, color='yellow', label=None)
plt.scatter(Opt, Tanh, color='blue', label='Tanh')
plt.scatter(Opt, Sigmoid, color='orange', label='Sigmoid')
plt.scatter(Opt, Softmax, color='red', label='Softmax')
plt.scatter(Opt, Relu, color='green', label='Relu')
#plt.plot(num, Softsign, color='pink', label='oftsign')
#plt.plot(num, Selu, color='yellow', label='Selu')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Neural Network Hyperbolic Tangent Error (XOR) ")
plt.xlabel("Opitimizers")
plt.ylabel("Loss (Binary Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary Entropy)')

# %% [markdown]
# Here is a comparison of six activations with five opitimzations. Tanh with a SGD optimization remained the best network.

# %%
loss3
# Out:
#      Tanh  Sigmoid  Softmax    Relu  softsign    Selu      code
# 0  0.0060   0.6941   0.6928  0.2270    0.0670  0.0154       SGD
# 1  0.0154   0.5561   0.0190  0.0195    0.0152  0.0459      Adam
# 2  0.0816   0.1057   0.0167  0.5126    0.0143  0.0475   RMSprop
# 3  0.3390   0.6931   0.6286  0.0830    0.4897  0.2133   Adagrad
# 4  0.0614   0.3301   0.0558  0.0708    0.0531  0.0931  Adadelta

# %%
plt.scatter(code, Tanh, color='blue', label='Tanh')
plt.scatter(code, Sigmoid, color='orange', label='Sigmoid')
plt.scatter(code, Softmax, color='red', label='Softmax')
plt.scatter(code, Relu, color='green', label='Relu')
plt.scatter(code, Softsign, color='pink', label='Softsign')
plt.scatter(code, Selu, color='yellow', label='Selu')
#plt.plot(code, Tanh, color='blue', label='Tanh')
#plt.plot(code, Sigmoid, color='orange', label='Sigmoid')
#plt.plot(code, Softmax, color='red', label='Softmax')
#plt.plot(code, Relu, color='green', label='Relu')
#plt.plot(code, Softsign, color='pink', label='oftsign')
#plt.plot(code, Selu, color='yellow', label='Selu')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Neural Network Various Model Error (XOR) ")
plt.xlabel("Activations")
plt.ylabel("Loss (Binary Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary Entropy)')

# %% [markdown]
# # Part 2

# %% [markdown]
# This table represents the loss for the Tanh with 1-5 hidden layers and 2-4 neurons. The two best networks were two hidden layers with two neurons and four hidden layers with three neurons. The remainer of the models produced 0.66 loss which is not ideal.

# %%
loss10
# Out:
#    HiddenLayers  Tanh_2  Tanh_3  Tanh_4
# 0             1  0.2824  0.6614  0.6609
# 1             2  0.2617  0.6607  0.6608
# 2             3  0.6608  0.6611  0.6607
# 3             4  0.6607  0.2756  0.6607
# 4             5  0.6606  0.6610  0.3068

# %%
plt.scatter(hide, Tanh2, color='blue', label=None)
plt.scatter(hide, Tanh3, color='orange', label=None)
plt.scatter(hide, Tanh4, color='red', label=None)
plt.plot(hide, Tanh2, color='blue', label='2 Neurons')
plt.plot(hide, Tanh3, color='orange', label='3 Neurons')
plt.plot(hide, Tanh4, color='red', label='4 Neurons')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Predicting Breast Cancer With Neural Network Hyperbolic Tangent (Error)")
plt.xlabel("Number of Hidden Layers")
plt.ylabel("Loss (Binary-cross Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary-cross Entropy)')

# %% [markdown]
# This plot represents the best activations with the adam opitimizer. Tanh remained the best model with four hidden layers and three neurons.

# %%
plt.scatter(numb, Loss1, color='orange', label='Error')
#plt.scatter(numb, Sig3, color='orange', label='Sigmoid')
#plt.scatter(numb, Softmax3, color='red', label='Softmax')
#plt.scatter(numb, Relu3, color='green', label='Relu')
#plt.plot(num, Softsign, color='pink', label='oftsign')
#plt.plot(num, Selu, color='yellow', label='Selu')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Optimal Neural Network Model Error")
plt.xlabel("Activation")
plt.ylabel("Loss (Binary Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary Entropy)')

# %%
loss5
# Out:
#     Tanh2  Sigmoid2  Softmax2   Relu2       Opt
# 0  0.6625    0.6941    0.6608  0.6602       SGD
# 1  0.2756    0.2500    0.6606  1.0000      Adam
# 2  0.6618    0.6609    0.6602  0.1521   RMSprop
# 3  0.6586    0.6588    0.6603  0.1862   Adagrad
# 4  0.6601    0.6612    0.6586  0.1266  Adadelta

# %% [markdown]
# The above table represents the best network incorporating other opitmizations. I discovered that the best model was Relu with four hidden layers and three neurons incorporating a Adadelta opitimization. The final loss was 0.12 with 400 epochs. The below scatterplot represents the various network performances. As you cans see Relu performed the best of all of the networks.

# %%
plt.scatter(o, R, color='orange', label='Relu')
plt.scatter(o, S, color='blue', label='Sigmoid')
plt.scatter(o, S1, color='red', label='Softmax')
plt.scatter(o, T, color='green', label='Tanh')
#plt.plot(num, Softsign, color='pink', label='oftsign')
#plt.plot(num, Selu, color='yellow', label='Selu')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Optimal Neural Network Model Error")
plt.xlabel("Opitimization")
plt.ylabel("Loss (Binary Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary Entropy)')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD  #Stochastic Gradient Descent

import numpy as np
# fix random seed for reproducibility
np.random.seed(7)
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\Pat\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
n = 50
xx = np.random.random((n,1))
yy = np.random.random((n,1))

# %%
X = np.array([np.array([xx,-xx,-xx,xx]),np.array([yy,-yy,yy,-yy])]).reshape(2,4*n).T
y = np.array([np.ones([2*n]),np.zeros([2*n])]).reshape(4*n)

# %%
plt.scatter(*zip(*X), c=y)

# %%
plt.scatter(Hidden, Tanh_2_neurons, color='blue', label=None)
plt.scatter(Hidden, Tanh_3_neurons, color='orange', label=None)
plt.scatter(Hidden, Tanh_4_neurons, color='red', label=None)
plt.plot(Hidden, Tanh_2_neurons, color='blue', label='2 Neurons')
plt.plot(Hidden, Tanh_3_neurons, color='orange', label='3 Neurons')
plt.plot(Hidden, Tanh_4_neurons, color='red', label='4 Neurons')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Neural Network Hyperbolic Tangent Error (XOR) ")
plt.xlabel("Number of Hidden Layers")
plt.ylabel("Loss (Binary Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary Entropy)')

# %%
# create model
model = Sequential()
model.add(Dense(4, input_dim=2, activation='tanh'))

model.add(Dense(4, activation='tanh'))
model.add(Dense(4, activation='tanh'))
#model.add(Dense(3, activation='softmax'))
#model.add(Dense(2, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
# Fit the model
model.fit(X, y, epochs=400, batch_size=2)
# evaluate the model
scores = model.evaluate(X, y)
#print(model.predict_proba(X).reshape(4*n))
# Out:
# Epoch 1/400
# 200/200 [==============================] - 3s 16ms/step - loss: 0.6965 - acc: 0.4600
# Epoch 2/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6879 - acc: 0.4950
# Epoch 3/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6779 - acc: 0.5350
# Epoch 4/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6703 - acc: 0.6650
# Epoch 5/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6599 - acc: 0.6050
# Epoch 6/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6503 - acc: 0.7100
# Epoch 7/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6379 - acc: 0.7750
# Epoch 8/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6249 - acc: 0.7600
# Epoch 9/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6092 - acc: 0.8050
# Epoch 10/400
# ...

# %%
plt.scatter(*zip(*X), c=model.predict_classes(X).reshape(4*n))

# %%
# create model
model = Sequential()
model.add(Dense(3, input_dim=2, activation='tanh'))

model.add(Dense(3, activation='tanh'))
model.add(Dense(3, activation='tanh'))
#model.add(Dense(2, activation='tanh'))
#model.add(Dense(2, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
# Fit the model
model.fit(X, y, epochs=400, batch_size=2)
# evaluate the model
scores = model.evaluate(X, y)
#print(model.predict_proba(X).reshape(4*n))
# Out:
# Epoch 1/400
# 200/200 [==============================] - 2s 10ms/step - loss: 0.6945 - acc: 0.5450
# Epoch 2/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6884 - acc: 0.5850
# Epoch 3/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6835 - acc: 0.5950
# Epoch 4/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6789 - acc: 0.6250
# Epoch 5/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6742 - acc: 0.6550A: 0s - loss: 0.6685 - acc: 0.67
# Epoch 6/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6695 - acc: 0.6700
# Epoch 7/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6638 - acc: 0.6450
# Epoch 8/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6581 - acc: 0.6650
# Epoch 9/400
# 200/200 [==============================] - 0s 2ms/step - loss: 0.6527 - acc: 0.6650
# Epoch 10/400
# ...

# %%
scores, model.metrics_names
# Out:
# ([0.3216276967525482, 0.87], ['loss', 'acc'])

# %%
plt.scatter(*zip(*X), c=model.predict_classes(X).reshape(4*n))

# %%
# create model
model = Sequential()
model.add(Dense(2, input_dim=2, activation='tanh'))

model.add(Dense(2, activation='tanh'))
model.add(Dense(2, activation='tanh'))
model.add(Dense(2, activation='tanh'))
#model.add(Dense(2, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
# Fit the model
model.fit(X, y, epochs=400, batch_size=2)
# evaluate the model
scores = model.evaluate(X, y)
#print(model.predict_proba(X).reshape(4*n))

# %%
scores, model.metrics_names

# %%
Tanh_loss = pd.read_csv('C:\JHU_Python\Tanh.csv')
Hidden=Tanh_loss.Hidden
Tanh_2_neurons=Tanh_loss.Tanh_2_neurons
Tanh_3_neurons=Tanh_loss.Tanh_3_neurons
Tanh_4_neurons=Tanh_loss.Tanh_4_neurons

# %%
loss5 = pd.read_csv('C:\JHU_Python\loss5.csv')

# %% [markdown]
# ##### loss = pd.read_csv('C:\JHU_Python\loss.csv')

# %%
Tanh=loss.Tanh

# %%
Sigmoid=loss.Sigmoid

# %%
Softmax=loss.Softmax

# %%
Relu=loss.Relu

# %%
Softsign=loss.softsign

# %%
Selu=loss.Selu

# %%
code=loss.code

# %%
plt.scatter(code, Tanh, color='blue', label='Tanh')
plt.scatter(code, Sigmoid, color='orange', label='Sigmoid')
plt.scatter(code, Softmax, color='red', label='Softmax')
plt.scatter(code, Relu, color='green', label='Relu')
plt.scatter(code, Softsign, color='pink', label='Softsign')
plt.scatter(code, Selu, color='yellow', label='Selu')
#plt.plot(code, Tanh, color='blue', label='Tanh')
#plt.plot(code, Sigmoid, color='orange', label='Sigmoid')
#plt.plot(code, Softmax, color='red', label='Softmax')
#plt.plot(code, Relu, color='green', label='Relu')
#plt.plot(code, Softsign, color='pink', label='oftsign')
#plt.plot(code, Selu, color='yellow', label='Selu')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Neural Network Various Model Error (XOR) ")
plt.xlabel("Activations")
plt.ylabel("Loss (Binary Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary Entropy)')

# %%
#plt.scatter(code, Tanh, color='blue', label=None)
#plt.scatter(code, Sigmoid, color='orange', label=None)
#plt.scatter(code, Softmax, color='red', label=None)
#plt.scatter(code, Relu, color='green', label=None)
#plt.scatter(code, Softsign, color='pink', label=None)
#plt.scatter(code, Selu, color='yellow', label=None)
plt.scatter(Opt, Tanh, color='blue', label='Tanh')
plt.scatter(Opt, Sigmoid, color='orange', label='Sigmoid')
plt.scatter(Opt, Softmax, color='red', label='Softmax')
plt.scatter(Opt, Relu, color='green', label='Relu')
#plt.plot(num, Softsign, color='pink', label='oftsign')
#plt.plot(num, Selu, color='yellow', label='Selu')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Neural Network Hyperbolic Tangent Error (XOR) ")
plt.xlabel("Number of Hidden Layers")
plt.ylabel("Loss (Binary Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary Entropy)')

# %%
loss2 = pd.read_csv('C:\JHU_Python\modelcomp.csv')

# %%
loss2
# Out:
#     Tanh1  Sigmoid1  Softmax1   Relu1       Opt
# 0  0.0060    0.6941    0.6928  0.2270       SGD
# 1  0.0154    0.5561    0.0190  0.0195      Adam
# 2  0.0816    0.1057    0.0167  0.5126   RMSprop
# 3  0.3390    0.6931    0.6286  0.0830   Adagrad
# 4  0.0614    0.3301    0.0558  0.0708  Adadelta

# %%
Opt=loss2.Opt

# %%
loss3= pd.read_csv('C:\JHU_Python\loss.csv')

# %% [markdown]
# # Part 2 Mushroom

# %%
mushroom= pd.read_csv('C:\JHU_Python\mushrooms.csv')

# %%
target = 'class' # The class we want to predict
labels = mushroom[target]
features = mushroom.drop(target, axis=1) # Remove the target class from the dataset

# %%
categorical = features.columns # Since every fearure is categorical we use features.columns
features = pd.concat([features, pd.get_dummies(features[categorical])], axis=1) # Convert every categorical feature with one hot encoding
features.drop(categorical, axis=1, inplace=True) # Drop the original feature, leave only the encoded ones

labels = pd.get_dummies(labels)['p'] # Encode the target class, 1 is deadly 0 is safe

# %%
# create model
model = Sequential()
model.add(Dense(3, input_dim=117, activation='tanh'))

model.add(Dense(3, activation='tanh'))
#model.add(Dense(3, activation='tanh'))
#model.add(Dense(2, activation='tanh'))
#model.add(Dense(2, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
# Fit the model
model.fit(features, labels, epochs=100, batch_size=2)
# evaluate the model
scores = model.evaluate(features, labels)
#print(model.predict_proba(X).reshape(4*n))
# Out:
# Epoch 1/100
# 8124/8124 [==============================] - 11s 1ms/step - loss: 0.1189 - acc: 0.9638
# Epoch 2/100
# 8124/8124 [==============================] - 11s 1ms/step - loss: 0.0123 - acc: 0.9991
# Epoch 3/100
# 8124/8124 [==============================] - 11s 1ms/step - loss: 0.0053 - acc: 0.9996
# Epoch 4/100
# 8124/8124 [==============================] - 12s 1ms/step - loss: 0.0030 - acc: 1.0000
# Epoch 5/100
# 8124/8124 [==============================] - 12s 1ms/step - loss: 0.0022 - acc: 1.0000
# Epoch 6/100
# 8124/8124 [==============================] - 11s 1ms/step - loss: 0.0017 - acc: 1.0000
# Epoch 7/100
# 8124/8124 [==============================] - 12s 1ms/step - loss: 0.0014 - acc: 1.0000
# Epoch 8/100
# 8124/8124 [==============================] - 11s 1ms/step - loss: 0.0012 - acc: 1.0000
# Epoch 9/100
# 8124/8124 [==============================] - 11s 1ms/step - loss: 0.0010 - acc: 1.0000
# Epoch 10/100
# ...

# %% [markdown]
#  # Breast Cancer Dataset

# %%
cancer = pd.read_csv('C:\JHU_Python\data/wdbc.data', header=None)

# %%
cancer[1].value_counts()
# Out:
# B    357
# M    212
# Name: 1, dtype: int64

# %%
Y = (cancer[1]=='M').astype(int) #this creates the Y depended classification variable based on the M "malignant"
X2 = cancer[[*range(2,31)]] #this creates a matrix of X variables based on the columns between columns 2 and 31. I will train test these variables againsts Y.

# %%
#import sklearn.preprocessing

# %%
#X = sklearn.preprocessing.MinMaxScaler().fit_transform(X)

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(X2, Y, train_size=.8)
# Out:
# C:\Users\Pat\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
# create model
model = Sequential()
model.add(Dense(3, input_dim=29, activation='softmax'))

model.add(Dense(3, activation='softmax'))
model.add(Dense(3, activation='softmax'))
model.add(Dense(3, activation='softmax'))
#model.add(Dense(3, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer='adadelta', metrics=['accuracy'])
# Fit the model
model.fit(X2, Y, epochs=400, batch_size=2)
# evaluate the model
scores = model.evaluate(X2, Y)
print(model.predict_proba(X2))
# Out:
# Epoch 1/400
# 569/569 [==============================] - 2s 4ms/step - loss: 0.6827 - acc: 0.5958
# Epoch 2/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6670 - acc: 0.6274
# Epoch 3/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6626 - acc: 0.6274TA: 0s - loss: 0.6
# Epoch 4/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6613 - acc: 0.6274
# Epoch 5/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6609 - acc: 0.6274
# Epoch 6/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6607 - acc: 0.6274
# Epoch 7/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6608 - acc: 0.6274
# Epoch 8/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6607 - acc: 0.6274
# Epoch 9/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6609 - acc: 0.6274
# Epoch 10/400
# ...

# %%
# create model
model = Sequential()
model.add(Dense(3, input_dim=29, activation='softmax'))

model.add(Dense(3, activation='softmax'))
model.add(Dense(3, activation='softmax'))
model.add(Dense(3, activation='softmax'))
#model.add(Dense(3, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer='Adadelta', metrics=['accuracy'])
# Fit the model
model.fit(X2, Y, epochs=400, batch_size=2)
# evaluate the model
scores = model.evaluate(X2, Y)
print(model.predict_proba(X2))
# Out:
# Epoch 1/400
# 569/569 [==============================] - 2s 4ms/step - loss: 0.7430 - acc: 0.3726
# Epoch 2/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6774 - acc: 0.6063
# Epoch 3/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6624 - acc: 0.6274
# Epoch 4/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6610 - acc: 0.6274
# Epoch 5/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6610 - acc: 0.6274
# Epoch 6/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6609 - acc: 0.6274
# Epoch 7/400
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6610 - acc: 0.6274
# Epoch 8/400
# 569/569 [==============================] - 1s 3ms/step - loss: 0.6610 - acc: 0.6274
# Epoch 9/400
# 569/569 [==============================] - 2s 3ms/step - loss: 0.6610 - acc: 0.6274
# Epoch 10/400
# ...

# %%
plt.scatter(hide, Tanh2, color='blue', label=None)
plt.scatter(hide, Tanh3, color='orange', label=None)
plt.scatter(hide, Tanh4, color='red', label=None)
plt.plot(hide, Tanh2, color='blue', label='2 Neurons')
plt.plot(hide, Tanh3, color='orange', label='3 Neurons')
plt.plot(hide, Tanh4, color='red', label='4 Neurons')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Predicting Breast Cancer With Neural Network Hyperbolic Tangent (Error)")
plt.xlabel("Number of Hidden Layers")
plt.ylabel("Loss (Binary-cross Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary-cross Entropy)')

# %%
loss10= pd.read_csv('C:\JHU_Python\loss10.csv')

# %%
loss4= pd.read_csv('C:\JHU_Python\loss4.csv')

# %%
hide=loss10.HiddenLayers

# %%
Tanh2 = loss10.Tanh_2
Tanh3 = loss10.Tanh_3
Tanh4 = loss10.Tanh_4

# %%
Loss1 = loss4.Loss
numb = loss4.numb

# %%
plt.scatter(numb, Loss1, color='orange', label='Error')
#plt.scatter(numb, Sig3, color='orange', label='Sigmoid')
#plt.scatter(numb, Softmax3, color='red', label='Softmax')
#plt.scatter(numb, Relu3, color='green', label='Relu')
#plt.plot(num, Softsign, color='pink', label='oftsign')
#plt.plot(num, Selu, color='yellow', label='Selu')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Optimal Neural Network Model Error")
plt.xlabel("Activation")
plt.ylabel("Loss (Binary Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary Entropy)')

# %%
T = loss4.Tanh2
S = loss4.Sigmoid2
S1 = loss4.Softmax2
R = loss4.Relu2
o = loss4.Opt

# %%
plt.scatter(o, R, color='orange', label='Relu')
plt.scatter(o, S, color='blue', label='Sigmoid')
plt.scatter(o, S1, color='red', label='Softmax')
plt.scatter(o, T, color='green', label='Tanh')
#plt.plot(num, Softsign, color='pink', label='oftsign')
#plt.plot(num, Selu, color='yellow', label='Selu')
plt.legend()
plt.xlim()
plt.ylim()
plt.title("Optimal Neural Network Model Error")
plt.xlabel("Activation")
plt.ylabel("Loss (Binary Entropy)")
# Out:
# Text(0,0.5,'Loss (Binary Entropy)')
